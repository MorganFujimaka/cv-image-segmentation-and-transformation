# %%
import numpy as np
import cv2
from skimage import io
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow

def url_to_image(url):
  print("downloading %s" % (url))
  return cv2.cvtColor(io.imread(url), cv2.COLOR_BGR2RGB)

def apply_rect(img, rect):
  mask = np.zeros(img.shape[:2], np.uint8)
  bgdModel = np.zeros((1, 65), np.float64)
  fgdModel = np.zeros((1, 65), np.float64)
  
  x, y, w, h = rect
  img_rect = cv2.rectangle(img.copy(), (x, y), (x+w, y+h), (255, 255, 0))
  cv2.grabCut(img, mask, rect, bgdModel, fgdModel, 5, cv2.GC_INIT_WITH_RECT)
  
  cv2_imshow(img_rect)

  mask2 = np.where((mask==2)|(mask==0), 0, 1).astype('uint8')
  img = img*mask2[:, :, np.newaxis]
  
  return img, mask2, bgdModel, fgdModel

def apply_manual_mask(img, mask, manual_mask_file, bgdModel, fgdModel):
  newmask = cv2.imread(manual_mask_file, 0)
  mask[newmask<50] = 0
  mask[newmask>200] = 1
  cv2_imshow(mask*255)

  cv2.grabCut(img, mask, None, bgdModel, fgdModel, 5, cv2.GC_INIT_WITH_MASK)
  mask2 = np.where((mask==2)|(mask==0), 0, 1).astype('uint8')

  return img*mask2[:, :, np.newaxis]

# %%
url_1 = "https://github.com/mdavydov/ComputerVisionCourse/raw/master/tasks/object/obj1.jpg"
img = url_to_image(url_1)

rect = (35, 25, 420, 220)
img_cut, mask2, bgdModel, fgdModel = apply_rect(img, rect)
cv2_imshow(img_cut)

img_cut = apply_manual_mask(img, mask2, 'newmask.png', bgdModel, fgdModel)
cv2_imshow(img_cut)
# Out:
# downloading https://github.com/mdavydov/ComputerVisionCourse/raw/master/tasks/object/obj1.jpg
# <PIL.Image.Image image mode=RGB size=480x269 at 0x7F8BB3A38E80>
# <PIL.Image.Image image mode=RGB size=480x269 at 0x7F8BB3A38E10>
# <PIL.Image.Image image mode=L size=480x269 at 0x7F8BB3A38E80>
# <PIL.Image.Image image mode=RGB size=480x269 at 0x7F8BB3A387F0>

# %%
url_2 = "https://github.com/mdavydov/ComputerVisionCourse/raw/master/tasks/object/obj2.jpg"
img = url_to_image(url_2)

rect = (105, 70, 325, 210)
img_cut, mask, bgdModel, fgdModel = apply_rect(img, rect)
cv2_imshow(img_cut)

img_cut = apply_manual_mask(img, mask, 'newmask2.png', bgdModel, fgdModel)
cv2_imshow(img_cut)
# Out:
# downloading https://github.com/mdavydov/ComputerVisionCourse/raw/master/tasks/object/obj2.jpg
# <PIL.Image.Image image mode=RGB size=480x320 at 0x7F8BB3A3BA58>
# <PIL.Image.Image image mode=RGB size=480x320 at 0x7F8BB3A3B240>
# <PIL.Image.Image image mode=L size=480x320 at 0x7F8BB3A3B3C8>
# <PIL.Image.Image image mode=RGB size=480x320 at 0x7F8BB3A3B3C8>

# %%
url_3 = "https://github.com/mdavydov/ComputerVisionCourse/raw/master/tasks/object/obj3.jpg"
img = url_to_image(url_3)

rect = (70, 50, 180, 160)
img, mask, bgdModel, fgdModel = apply_rect(img, rect)

cv2_imshow(img)
# Out:
# downloading https://github.com/mdavydov/ComputerVisionCourse/raw/master/tasks/object/obj3.jpg
# <PIL.Image.Image image mode=RGB size=480x376 at 0x7F8BB3A50D30>
# <PIL.Image.Image image mode=RGB size=480x376 at 0x7F8BB3A50860>

# %%
url_4 = "https://github.com/mdavydov/ComputerVisionCourse/raw/master/tasks/object/obj4.jpg"
img = url_to_image(url_4)

rect = (65, 25, 350, 300)
img_cut, mask, bgdModel, fgdModel = apply_rect(img, rect)
cv2_imshow(img_cut)

img_cut = apply_manual_mask(img, mask, 'newmask3.png', bgdModel, fgdModel)
cv2_imshow(img_cut)
# Out:
# downloading https://github.com/mdavydov/ComputerVisionCourse/raw/master/tasks/object/obj4.jpg
# <PIL.Image.Image image mode=RGB size=480x319 at 0x7F8BB39E65C0>
# <PIL.Image.Image image mode=RGB size=480x319 at 0x7F8BB39E6400>
# <PIL.Image.Image image mode=L size=480x319 at 0x7F8BB39E6128>
# <PIL.Image.Image image mode=RGB size=480x319 at 0x7F8BB39E6BA8>

# %%
url_5 = "https://github.com/mdavydov/ComputerVisionCourse/raw/master/tasks/object/obj5.jpg"
img = url_to_image(url_5)

rect = (45, 15, 410, 320)
img_cut, mask, bgdModel, fgdModel = apply_rect(img, rect)
cv2_imshow(img_cut)

img_cut = apply_manual_mask(img, mask, 'newmask4.png', bgdModel, fgdModel)
cv2_imshow(img_cut)
# Out:
# downloading https://github.com/mdavydov/ComputerVisionCourse/raw/master/tasks/object/obj5.jpg
# <PIL.Image.Image image mode=RGB size=480x320 at 0x7F8BB39E9CF8>
# <PIL.Image.Image image mode=RGB size=480x320 at 0x7F8BB39E9C88>
# <PIL.Image.Image image mode=L size=480x320 at 0x7F8BB39E96A0>
# <PIL.Image.Image image mode=RGB size=480x320 at 0x7F8BB39E9CF8>

# %%
url_6 = "https://github.com/mdavydov/ComputerVisionCourse/raw/master/tasks/object/obj6.jpg"
img = url_to_image(url_6)

rect = (0, 55, 240, 400)
img_cut, mask, bgdModel, fgdModel = apply_rect(img, rect)
cv2_imshow(img_cut)

img_cut = apply_manual_mask(img, mask, 'newmask5.png', bgdModel, fgdModel)
cv2_imshow(img_cut)
# Out:
# downloading https://github.com/mdavydov/ComputerVisionCourse/raw/master/tasks/object/obj6.jpg
# <PIL.Image.Image image mode=RGB size=319x480 at 0x7F8BB39F2F28>
# <PIL.Image.Image image mode=RGB size=319x480 at 0x7F8BB39E9160>
# <PIL.Image.Image image mode=L size=319x480 at 0x7F8BB39F2630>
# <PIL.Image.Image image mode=RGB size=319x480 at 0x7F8BB39F2630>
